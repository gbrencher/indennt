# %% [markdown]
# # Correct all igrams with MuRP

# %%
from glob import glob
import xarray as xr
import rasterio as rio
import rioxarray
import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.metrics import mean_squared_error

# %%
# load in single igram and other data 
def hyp3_to_xarray_single(path):
    '''
    Reads unwrapped phase, coherence, and DEM into xarray dataset from single hyp3 folder 
    '''
    # globs for data to load
    unw_phase_path = glob(f'{path}/*unw_phase.tif')[0]
    corr_path = glob(f'{path}/*corr.tif')[0]
    dem_path = glob(f'{path}/*dem.tif')[0]

    # list granules for coordinate
    granule = os.path.split(unw_phase_path)[-1][0:-14]

    # read unw_phase into data array and assign coordinates
    da = xr.open_dataset(unw_phase_path)
    da = da.assign_coords({'granule':('granule', [granule])})
    
    # concatenate into dataset and rename variable
    ds = da.rename({'band_data': 'unw_phase'})

    #open coherence and dem into datasets
    corr_ds = xr.open_dataset(corr_path)
    dem_ds = xr.open_dataset(dem_path)

    # add coherence and dem to unw_phase dataset
    ds['coherence'] = (('band', 'y', 'x'), corr_ds.band_data.values)
    ds['elevation'] = (('band', 'y', 'x'), dem_ds.band_data.values)

    # remove band coordinate
    ds = ds.squeeze()

    return ds

# %%
def select_refs(ds, corr_thresh=0.9, n_refs=1000):
    ref_list = []
    ref_counter = 0
    while ref_counter < n_refs:
        x, y = np.random.randint(0, len(ds.x)), np.random.randint(0, len(ds.y))
        if [x, y] not in ref_list:
            if ds.coherence.isel(x=x, y=y) >= corr_thresh:
                ref_list.append([x, y])
                ref_counter +=1
    return ref_list

def plot_points(ds, refs, output_dir):
    x, y = zip(*refs)
    
    f, ax = plt.subplots()
    ax.imshow(ds.elevation, cmap='viridis')
    ax.plot(x, y, marker='o', linestyle='', color='Orange')
    ax.set_title('reference points')
    ax.set_aspect('equal')

    plt.savefig(f'{output_dir}/ref_points.png', dpi=300)

def sample_refs(ds, refs):
    ref_phase = []
    ref_elevation = []
    for ref in refs:
        ref_elevation.append(ds.elevation.isel(x=ref[0], y=ref[1]).item())
        ref_phase.append(ds.unw_phase.isel(x=ref[0], y=ref[1]).item())
    return ref_phase, ref_elevation

def plot_first_scatter(ref_phase, ref_elevation, output_dir):
    f, ax = plt.subplots()
    ax.plot(ref_elevation, ref_phase, marker='o', linestyle='')
    ax.set_xlabel('elevation')
    ax.set_ylabel('phase')
    ax.set_title('elevation and phase of ref points in first igram')
   
    plt.savefig(f'{output_dir}/first_igram_elevation_phase.png', dpi=300)

def linear_fits(ds, ref_phase, ref_elevation):
    model = linear_model.LinearRegression() 
    inputs = np.array((ref_elevation, ref_phase)).transpose()
    inputs = inputs[~np.isnan(inputs).any(axis=1)]
    model.fit(inputs[:, 0].reshape(-1, 1), inputs[:, 1])
    fits = [model.coef_.item(), model.intercept_]
    return fits

def correct_igrams(ds, fits):
    slope, intercept = fits[0], fits[1]
    ds['unw_phase_MuRP'] = ds.unw_phase - (ds.elevation.values*slope+intercept)
    return ds

def plot_correction(ds, output_dir):
    f, ax = plt.subplots(2, 1, figsize=(10, 5))
    ds.unw_phase_MuRP.plot(ax=ax[0], vmin=-5, vmax=5, cmap='RdBu')
    ax[0].set_aspect('equal')
    ax[0].set_title('MuRP corrected mean phase')
    ds.unw_phase.plot(ax=ax[1], vmin=-5, vmax=5, cmap='RdBu')
    ax[1].set_aspect('equal')
    ax[1].set_title('uncorrected mean phase')
    plt.tight_layout()

    plt.savefig(f'{output_dir}/MuRP_correction.png', dpi=300)

# single function
def MuRP(ds, corr_thresh=0.8, n_refs=1000, figs=True, fig_dir='../figs'):
    '''
    Correct unwrapped phase with linear fit to multiple stable reference points
    '''
    print('selecting reference points')
    refs = select_refs(ds)
    
    print('sampling reference points')
    ref_values, ref_elevation = sample_refs(ds, refs)
    
    print('calculating linear fits')
    fits = linear_fits(ds, ref_values, ref_elevation)
    
    print('correcting interferograms')
    ds = correct_igrams(ds, fits)

    if figs==True:
        os.makedirs(fig_dir, exist_ok=True)
        print('saving figures')
        plot_points(ds, refs, fig_dir)
        plot_first_scatter(ref_values, ref_elevation, fig_dir)
        plot_correction(ds, '../figs')

    return ds

# %%
def multi_year_MuRP(orbit_list, year_list):
    for orbit in orbit_list:
        for year in year_list:
            print(f'working on {orbit}, {year}')
            hyp3_path = f'/mnt/d/indennt/hyp3_app/{orbit}/{year}'
            hyp3_list = os.listdir(hyp3_path)
            for i, granule in enumerate(hyp3_list):
                granule_path = f'{hyp3_path}/{granule}'
                if os.path.exists(f'{granule_path}/{granule}_unw_phase_MuRP.tif'):
                    print(f'unw_phase_MuRP already in {granule}, skipping') 
                    continue
                print(f'working on {granule}, {i}/{len(hyp3_list)}')
                ds = hyp3_to_xarray_single(granule_path)
                ds = MuRP(ds, figs=False)
                ds.unw_phase_MuRP.rio.to_raster(f'{granule_path}/{granule}_unw_phase_MuRP.tif')

# %%
multi_year_MuRP(['AT137'], ['2017', '2018', '2019', '2020', '2021'])
# Out:
# working on AT137
# working on AT137, 2017
# working on S1BB_20170613T011036_20170625T011036_VVP012_INT40_G_ueF_0FFD, 0/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20170613T011036_20170707T011037_VVP024_INT40_G_ueF_BDAA, 1/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20170613T011036_20170731T011038_VVP048_INT40_G_ueF_52B1, 2/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20170613T011036_20170812T011039_VVP060_INT40_G_ueF_187A, 3/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20170613T011036_20170824T011040_VVP072_INT40_G_ueF_A6C1, 4/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20170613T011036_20170905T011040_VVP084_INT40_G_ueF_8684, 5/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20170613T011036_20170917T011041_VVP096_INT40_G_ueF_A773, 6/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20170613T011036_20170929T011041_VVP108_INT40_G_ueF_A0CA, 7/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20170613T011036_20171011T011041_VVP120_INT40_G_ueF_708A, 8/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20170625T011036_20170707T011037_VVP012_INT40_G_ueF_5390, 9/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20170625T011036_20170731T011038_VVP036_INT40_G_ueF_C662, 10/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20170625T011036_20170812T011039_VVP048_INT40_G_ueF_F0A9, 11/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20170625T011036_20170824T011040_VVP060_INT40_G_ueF_963E, 12/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20170625T011036_20170905T011040_VVP072_INT40_G_ueF_B0E9, 13/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20170625T011036_20170917T011041_VVP084_INT40_G_ueF_0D9B, 14/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20170625T011036_20170929T011041_VVP096_INT40_G_ueF_93D8, 15/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20170625T011036_20171011T011041_VVP108_INT40_G_ueF_D4BD, 16/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20170707T011037_20170731T011038_VVP024_INT40_G_ueF_A50E, 17/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20170707T011037_20170812T011039_VVP036_INT40_G_ueF_655A, 18/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20170707T011037_20170824T011040_VVP048_INT40_G_ueF_57B4, 19/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20170707T011037_20170905T011040_VVP060_INT40_G_ueF_E834, 20/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20170707T011037_20170917T011041_VVP072_INT40_G_ueF_3562, 21/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20170707T011037_20170929T011041_VVP084_INT40_G_ueF_7F20, 22/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20170707T011037_20171011T011041_VVP096_INT40_G_ueF_E048, 23/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20170731T011038_20170812T011039_VVP012_INT40_G_ueF_DA06, 24/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20170731T011038_20170824T011040_VVP024_INT40_G_ueF_760A, 25/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20170731T011038_20170905T011040_VVP036_INT40_G_ueF_F09C, 26/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20170731T011038_20170917T011041_VVP048_INT40_G_ueF_3F7B, 27/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20170731T011038_20170929T011041_VVP060_INT40_G_ueF_3404, 28/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20170731T011038_20171011T011041_VVP072_INT40_G_ueF_2044, 29/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20170812T011039_20170824T011040_VVP012_INT40_G_ueF_3177, 30/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20170812T011039_20170905T011040_VVP024_INT40_G_ueF_051D, 31/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20170812T011039_20170917T011041_VVP036_INT40_G_ueF_8DDB, 32/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20170812T011039_20170929T011041_VVP048_INT40_G_ueF_842C, 33/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20170812T011039_20171011T011041_VVP060_INT40_G_ueF_CEAB, 34/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20170824T011040_20170905T011040_VVP012_INT40_G_ueF_2835, 35/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20170824T011040_20170917T011041_VVP024_INT40_G_ueF_2D2B, 36/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20170824T011040_20170929T011041_VVP036_INT40_G_ueF_8E34, 37/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20170824T011040_20171011T011041_VVP048_INT40_G_ueF_66CB, 38/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20170905T011040_20170917T011041_VVP012_INT40_G_ueF_402B, 39/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20170905T011040_20170929T011041_VVP024_INT40_G_ueF_DF31, 40/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20170905T011040_20171011T011041_VVP036_INT40_G_ueF_FEFE, 41/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20170917T011041_20170929T011041_VVP012_INT40_G_ueF_F22E, 42/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20170917T011041_20171011T011041_VVP024_INT40_G_ueF_E2E2, 43/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20170929T011041_20171011T011041_VVP012_INT40_G_ueF_C8D2, 44/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on AT137, 2018
# working on S1BB_20180608T011042_20180702T011043_VVP024_INT40_G_ueF_EBD9, 0/40
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20180608T011042_20180714T011044_VVP036_INT40_G_ueF_4787, 1/40
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20180608T011042_20180726T011045_VVP048_INT40_G_ueF_0B05, 2/40
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20180608T011042_20180807T011045_VVP060_INT40_G_ueF_EBDA, 3/40
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20180702T011043_20180714T011044_VVP012_INT40_G_ueF_3BB0, 4/40
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20180702T011043_20180726T011045_VVP024_INT40_G_ueF_6650, 5/40
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20180702T011043_20180807T011045_VVP036_INT40_G_ueF_BD7F, 6/40
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20180702T011043_20180819T011046_VVP048_INT40_G_ueF_8922, 7/40
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20180702T011043_20180831T011046_VVP060_INT40_G_ueF_D449, 8/40
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20180702T011043_20180912T011047_VVP072_INT40_G_ueF_F834, 9/40
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20180702T011043_20180924T011047_VVP084_INT40_G_ueF_32A5, 10/40
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20180702T011043_20181006T011048_VVP096_INT40_G_ueF_0F4E, 11/40
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20180714T011044_20180726T011045_VVP012_INT40_G_ueF_95AC, 12/40
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20180714T011044_20180807T011045_VVP024_INT40_G_ueF_0B4F, 13/40
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20180714T011044_20180819T011046_VVP036_INT40_G_ueF_BFA2, 14/40
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20180714T011044_20180831T011046_VVP048_INT40_G_ueF_45D3, 15/40
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20180714T011044_20180912T011047_VVP060_INT40_G_ueF_4BF7, 16/40
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20180714T011044_20180924T011047_VVP072_INT40_G_ueF_D65E, 17/40
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20180714T011044_20181006T011048_VVP084_INT40_G_ueF_F669, 18/40
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20180726T011045_20180807T011045_VVP012_INT40_G_ueF_8BDD, 19/40
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20180726T011045_20180819T011046_VVP024_INT40_G_ueF_B264, 20/40
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20180726T011045_20180831T011046_VVP036_INT40_G_ueF_C8F1, 21/40
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20180726T011045_20180912T011047_VVP048_INT40_G_ueF_CA83, 22/40
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20180726T011045_20180924T011047_VVP060_INT40_G_ueF_9870, 23/40
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20180726T011045_20181006T011048_VVP072_INT40_G_ueF_7429, 24/40
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20180807T011045_20180819T011046_VVP012_INT40_G_ueF_BBE3, 25/40
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20180807T011045_20180831T011046_VVP024_INT40_G_ueF_8DAC, 26/40
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20180807T011045_20180912T011047_VVP036_INT40_G_ueF_EBA6, 27/40
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20180807T011045_20180924T011047_VVP048_INT40_G_ueF_A1B1, 28/40
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20180807T011045_20181006T011048_VVP060_INT40_G_ueF_8E6E, 29/40
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20180819T011046_20180831T011046_VVP012_INT40_G_ueF_56C2, 30/40
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20180819T011046_20180912T011047_VVP024_INT40_G_ueF_8007, 31/40
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20180819T011046_20180924T011047_VVP036_INT40_G_ueF_DBEE, 32/40
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20180819T011046_20181006T011048_VVP048_INT40_G_ueF_F3DA, 33/40
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20180831T011046_20180912T011047_VVP012_INT40_G_ueF_B1CC, 34/40
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20180831T011046_20180924T011047_VVP024_INT40_G_ueF_BE72, 35/40
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20180831T011046_20181006T011048_VVP036_INT40_G_ueF_4B66, 36/40
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20180912T011047_20180924T011047_VVP012_INT40_G_ueF_15B3, 37/40
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20180912T011047_20181006T011048_VVP024_INT40_G_ueF_D629, 38/40
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20180924T011047_20181006T011048_VVP012_INT40_G_ueF_F6E0, 39/40
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on AT137, 2019
# working on S1BB_20190603T011048_20190615T011048_VVP012_INT40_G_ueF_DE9D, 0/66
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20190603T011048_20190627T011049_VVP024_INT40_G_ueF_9268, 1/66
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20190603T011048_20190709T011050_VVP036_INT40_G_ueF_20EB, 2/66
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20190603T011048_20190721T011050_VVP048_INT40_G_ueF_B436, 3/66
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20190603T011048_20190802T011051_VVP060_INT40_G_ueF_4AFB, 4/66
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20190603T011048_20190814T011052_VVP072_INT40_G_ueF_8300, 5/66
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20190603T011048_20190826T011053_VVP084_INT40_G_ueF_528D, 6/66
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20190603T011048_20190907T011053_VVP096_INT40_G_ueF_0DE8, 7/66
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20190603T011048_20190919T011054_VVP108_INT40_G_ueF_8EB3, 8/66
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20190603T011048_20191001T011054_VVP120_INT40_G_ueF_C4E1, 9/66
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20190603T011048_20191013T011054_VVP132_INT40_G_ueF_0141, 10/66
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20190615T011048_20190627T011049_VVP012_INT40_G_ueF_8CB5, 11/66
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20190615T011048_20190709T011050_VVP024_INT40_G_ueF_F28F, 12/66
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20190615T011048_20190721T011050_VVP036_INT40_G_ueF_ED53, 13/66
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20190615T011048_20190802T011051_VVP048_INT40_G_ueF_7861, 14/66
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20190615T011048_20190814T011052_VVP060_INT40_G_ueF_809B, 15/66
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20190615T011048_20190826T011053_VVP072_INT40_G_ueF_70E5, 16/66
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20190615T011048_20190907T011053_VVP084_INT40_G_ueF_D82F, 17/66
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20190615T011048_20190919T011054_VVP096_INT40_G_ueF_CE68, 18/66
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20190615T011048_20191001T011054_VVP108_INT40_G_ueF_5FA5, 19/66
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20190615T011048_20191013T011054_VVP120_INT40_G_ueF_0EC9, 20/66
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20190627T011049_20190709T011050_VVP012_INT40_G_ueF_A6EF, 21/66
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20190627T011049_20190721T011050_VVP024_INT40_G_ueF_515C, 22/66
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20190627T011049_20190802T011051_VVP036_INT40_G_ueF_4C64, 23/66
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20190627T011049_20190814T011052_VVP048_INT40_G_ueF_5D03, 24/66
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20190627T011049_20190826T011053_VVP060_INT40_G_ueF_6474, 25/66
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20190627T011049_20190907T011053_VVP072_INT40_G_ueF_76BB, 26/66
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20190627T011049_20190919T011054_VVP084_INT40_G_ueF_3A2C, 27/66
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20190627T011049_20191001T011054_VVP096_INT40_G_ueF_441E, 28/66
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20190627T011049_20191013T011054_VVP108_INT40_G_ueF_360F, 29/66
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20190709T011050_20190721T011050_VVP012_INT40_G_ueF_F9F6, 30/66
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20190709T011050_20190802T011051_VVP024_INT40_G_ueF_F909, 31/66
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20190709T011050_20190814T011052_VVP036_INT40_G_ueF_13E3, 32/66
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20190709T011050_20190826T011053_VVP048_INT40_G_ueF_AA55, 33/66
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20190709T011050_20190907T011053_VVP060_INT40_G_ueF_0B22, 34/66
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20190709T011050_20190919T011054_VVP072_INT40_G_ueF_C8F9, 35/66
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20190709T011050_20191001T011054_VVP084_INT40_G_ueF_DD9D, 36/66
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20190709T011050_20191013T011054_VVP096_INT40_G_ueF_A2C2, 37/66
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20190721T011050_20190802T011051_VVP012_INT40_G_ueF_663B, 38/66
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20190721T011050_20190814T011052_VVP024_INT40_G_ueF_8F71, 39/66
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20190721T011050_20190826T011053_VVP036_INT40_G_ueF_724F, 40/66
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20190721T011050_20190907T011053_VVP048_INT40_G_ueF_9083, 41/66
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20190721T011050_20190919T011054_VVP060_INT40_G_ueF_AA6B, 42/66
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20190721T011050_20191001T011054_VVP072_INT40_G_ueF_5507, 43/66
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20190721T011050_20191013T011054_VVP084_INT40_G_ueF_DB3E, 44/66
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20190802T011051_20190814T011052_VVP012_INT40_G_ueF_090C, 45/66
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20190802T011051_20190826T011053_VVP024_INT40_G_ueF_F78E, 46/66
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20190802T011051_20190907T011053_VVP036_INT40_G_ueF_A2E5, 47/66
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20190802T011051_20190919T011054_VVP048_INT40_G_ueF_CCA0, 48/66
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20190802T011051_20191001T011054_VVP060_INT40_G_ueF_8055, 49/66
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20190802T011051_20191013T011054_VVP072_INT40_G_ueF_3981, 50/66
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20190814T011052_20190826T011053_VVP012_INT40_G_ueF_E7AE, 51/66
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20190814T011052_20190907T011053_VVP024_INT40_G_ueF_0F87, 52/66
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20190814T011052_20190919T011054_VVP036_INT40_G_ueF_D186, 53/66
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20190814T011052_20191001T011054_VVP048_INT40_G_ueF_F341, 54/66
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20190814T011052_20191013T011054_VVP060_INT40_G_ueF_D3D8, 55/66
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20190826T011053_20190907T011053_VVP012_INT40_G_ueF_5733, 56/66
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20190826T011053_20190919T011054_VVP024_INT40_G_ueF_8490, 57/66
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20190826T011053_20191001T011054_VVP036_INT40_G_ueF_CB55, 58/66
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20190826T011053_20191013T011054_VVP048_INT40_G_ueF_C2DA, 59/66
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20190907T011053_20190919T011054_VVP012_INT40_G_ueF_5919, 60/66
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20190907T011053_20191001T011054_VVP024_INT40_G_ueF_AAF1, 61/66
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20190907T011053_20191013T011054_VVP036_INT40_G_ueF_7D3D, 62/66
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20190919T011054_20191001T011054_VVP012_INT40_G_ueF_C979, 63/66
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20190919T011054_20191013T011054_VVP024_INT40_G_ueF_D24A, 64/66
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20191001T011054_20191013T011054_VVP012_INT40_G_ueF_705F, 65/66
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on AT137, 2020
# working on S1BB_20200609T011055_20200621T011055_VVP012_INT40_G_ueF_BBA0, 0/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20200609T011055_20200715T011056_VVP036_INT40_G_ueF_165D, 1/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20200609T011055_20200727T011057_VVP048_INT40_G_ueF_8774, 2/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20200609T011055_20200808T011058_VVP060_INT40_G_ueF_80E5, 3/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20200609T011055_20200820T011059_VVP072_INT40_G_ueF_319A, 4/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20200609T011055_20200901T011059_VVP084_INT40_G_ueF_0F53, 5/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20200609T011055_20200913T011100_VVP096_INT40_G_ueF_4841, 6/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20200609T011055_20200925T011100_VVP108_INT40_G_ueF_CC9C, 7/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20200609T011055_20201007T011100_VVP120_INT40_G_ueF_D55B, 8/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20200621T011055_20200715T011056_VVP024_INT40_G_ueF_FEF3, 9/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20200621T011055_20200727T011057_VVP036_INT40_G_ueF_8EC9, 10/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20200621T011055_20200808T011058_VVP048_INT40_G_ueF_76AC, 11/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20200621T011055_20200820T011059_VVP060_INT40_G_ueF_8371, 12/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20200621T011055_20200901T011059_VVP072_INT40_G_ueF_9B6F, 13/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20200621T011055_20200913T011100_VVP084_INT40_G_ueF_C3E8, 14/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20200621T011055_20200925T011100_VVP096_INT40_G_ueF_4EA2, 15/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20200621T011055_20201007T011100_VVP108_INT40_G_ueF_BA5B, 16/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20200715T011056_20200727T011057_VVP012_INT40_G_ueF_FE0F, 17/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20200715T011056_20200808T011058_VVP024_INT40_G_ueF_DE74, 18/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20200715T011056_20200820T011059_VVP036_INT40_G_ueF_2134, 19/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20200715T011056_20200901T011059_VVP048_INT40_G_ueF_6072, 20/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20200715T011056_20200913T011100_VVP060_INT40_G_ueF_D4BD, 21/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20200715T011056_20200925T011100_VVP072_INT40_G_ueF_1B83, 22/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20200715T011056_20201007T011100_VVP084_INT40_G_ueF_60FD, 23/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20200727T011057_20200808T011058_VVP012_INT40_G_ueF_0824, 24/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20200727T011057_20200820T011059_VVP024_INT40_G_ueF_6238, 25/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20200727T011057_20200901T011059_VVP036_INT40_G_ueF_A2C6, 26/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20200727T011057_20200913T011100_VVP048_INT40_G_ueF_8AED, 27/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20200727T011057_20200925T011100_VVP060_INT40_G_ueF_43D3, 28/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20200727T011057_20201007T011100_VVP072_INT40_G_ueF_F68B, 29/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20200808T011058_20200820T011059_VVP012_INT40_G_ueF_B326, 30/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20200808T011058_20200901T011059_VVP024_INT40_G_ueF_D228, 31/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20200808T011058_20200913T011100_VVP036_INT40_G_ueF_A92C, 32/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20200808T011058_20200925T011100_VVP048_INT40_G_ueF_BFC4, 33/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20200808T011058_20201007T011100_VVP060_INT40_G_ueF_70CB, 34/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20200820T011059_20200901T011059_VVP012_INT40_G_ueF_BE5B, 35/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20200820T011059_20200913T011100_VVP024_INT40_G_ueF_6A1C, 36/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20200820T011059_20200925T011100_VVP036_INT40_G_ueF_6AE8, 37/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20200820T011059_20201007T011100_VVP048_INT40_G_ueF_5C64, 38/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20200901T011059_20200913T011100_VVP012_INT40_G_ueF_9462, 39/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20200901T011059_20200925T011100_VVP024_INT40_G_ueF_9246, 40/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20200901T011059_20201007T011100_VVP036_INT40_G_ueF_49A4, 41/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20200913T011100_20200925T011100_VVP012_INT40_G_ueF_B1F5, 42/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20200913T011100_20201007T011100_VVP024_INT40_G_ueF_26E7, 43/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20200925T011100_20201007T011100_VVP012_INT40_G_ueF_910F, 44/45
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on AT137, 2021
# working on S1BB_20210604T011100_20210616T011101_VVP012_INT40_G_ueF_4BF7, 0/55
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20210604T011100_20210628T011101_VVP024_INT40_G_ueF_E592, 1/55
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20210604T011100_20210710T011102_VVP036_INT40_G_ueF_C8C4, 2/55
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20210604T011100_20210722T011103_VVP048_INT40_G_ueF_F7B1, 3/55
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20210604T011100_20210803T011104_VVP060_INT40_G_ueF_8A4E, 4/55
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20210604T011100_20210815T011104_VVP072_INT40_G_ueF_3D8E, 5/55
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20210604T011100_20210827T011105_VVP084_INT40_G_ueF_D203, 6/55
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20210604T011100_20210908T011105_VVP096_INT40_G_ueF_2C8F, 7/55
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20210604T011100_20210920T011106_VVP108_INT40_G_ueF_41FA, 8/55
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20210604T011100_20211014T011106_VVP132_INT40_G_ueF_ED6B, 9/55
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20210616T011101_20210628T011101_VVP012_INT40_G_ueF_C9BB, 10/55
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20210616T011101_20210710T011102_VVP024_INT40_G_ueF_D6D5, 11/55
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20210616T011101_20210722T011103_VVP036_INT40_G_ueF_51EE, 12/55
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20210616T011101_20210803T011104_VVP048_INT40_G_ueF_54EA, 13/55
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20210616T011101_20210815T011104_VVP060_INT40_G_ueF_CBEA, 14/55
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20210616T011101_20210827T011105_VVP072_INT40_G_ueF_8E61, 15/55
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20210616T011101_20210908T011105_VVP084_INT40_G_ueF_57F3, 16/55
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20210616T011101_20210920T011106_VVP096_INT40_G_ueF_F27D, 17/55
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20210616T011101_20211014T011106_VVP120_INT40_G_ueF_58D5, 18/55
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20210628T011101_20210710T011102_VVP012_INT40_G_ueF_54CE, 19/55
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20210628T011101_20210722T011103_VVP024_INT40_G_ueF_42BA, 20/55
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20210628T011101_20210803T011104_VVP036_INT40_G_ueF_C998, 21/55
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20210628T011101_20210815T011104_VVP048_INT40_G_ueF_3883, 22/55
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20210628T011101_20210827T011105_VVP060_INT40_G_ueF_C3BB, 23/55
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20210628T011101_20210908T011105_VVP072_INT40_G_ueF_57E1, 24/55
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20210628T011101_20210920T011106_VVP084_INT40_G_ueF_8BFD, 25/55
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20210628T011101_20211014T011106_VVP108_INT40_G_ueF_7EB6, 26/55
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20210710T011102_20210722T011103_VVP012_INT40_G_ueF_D3E7, 27/55
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20210710T011102_20210803T011104_VVP024_INT40_G_ueF_82F1, 28/55
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20210710T011102_20210815T011104_VVP036_INT40_G_ueF_85C9, 29/55
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20210710T011102_20210827T011105_VVP048_INT40_G_ueF_F22B, 30/55
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20210710T011102_20210908T011105_VVP060_INT40_G_ueF_5A84, 31/55
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20210710T011102_20210920T011106_VVP072_INT40_G_ueF_73DB, 32/55
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20210710T011102_20211014T011106_VVP096_INT40_G_ueF_0104, 33/55
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20210722T011103_20210803T011104_VVP012_INT40_G_ueF_9551, 34/55
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20210722T011103_20210815T011104_VVP024_INT40_G_ueF_BEB7, 35/55
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20210722T011103_20210827T011105_VVP036_INT40_G_ueF_6F6E, 36/55
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20210722T011103_20210908T011105_VVP048_INT40_G_ueF_048F, 37/55
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20210722T011103_20210920T011106_VVP060_INT40_G_ueF_73F4, 38/55
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20210722T011103_20211014T011106_VVP084_INT40_G_ueF_B1DF, 39/55
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20210803T011104_20210815T011104_VVP012_INT40_G_ueF_A209, 40/55
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20210803T011104_20210827T011105_VVP024_INT40_G_ueF_2CE2, 41/55
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20210803T011104_20210908T011105_VVP036_INT40_G_ueF_CF28, 42/55
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20210803T011104_20210920T011106_VVP048_INT40_G_ueF_A35B, 43/55
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20210803T011104_20211014T011106_VVP072_INT40_G_ueF_CE3E, 44/55
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20210815T011104_20210827T011105_VVP012_INT40_G_ueF_0181, 45/55
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20210815T011104_20210908T011105_VVP024_INT40_G_ueF_5B27, 46/55
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20210815T011104_20210920T011106_VVP036_INT40_G_ueF_3B1F, 47/55
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20210815T011104_20211014T011106_VVP060_INT40_G_ueF_B475, 48/55
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20210827T011105_20210908T011105_VVP012_INT40_G_ueF_E582, 49/55
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20210827T011105_20210920T011106_VVP024_INT40_G_ueF_C091, 50/55
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20210827T011105_20211014T011106_VVP048_INT40_G_ueF_4607, 51/55
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20210908T011105_20210920T011106_VVP012_INT40_G_ueF_D628, 52/55
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20210908T011105_20211014T011106_VVP036_INT40_G_ueF_CC6D, 53/55
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
# working on S1BB_20210920T011106_20211014T011106_VVP024_INT40_G_ueF_D3A1, 54/55
# selecting reference points
# sampling reference points
# calculating linear fits
# correcting interferograms
